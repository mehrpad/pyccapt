# %% [markdown]
# # Cameca Raw Import Workflow
#
# Use this tutorial to import `RHIT`, `STR`, and `HITS` files from Cameca LEAP systems,
# optionally transfer calibration from matching `EPOS`/`RHIT` files, and export a
# PyCCAPT-style processed dataset for the rest of the workflow.

# %%
# %load_ext autoreload
# %autoreload 2

from pyccapt.calibration.core import share_variables
from pyccapt.calibration.tutorials.tutorials_helpers import helper_cameca_raw_import

variables = share_variables.Variables()

# %%
helper_cameca_raw_import.call_cameca_raw_import_workflow(variables)

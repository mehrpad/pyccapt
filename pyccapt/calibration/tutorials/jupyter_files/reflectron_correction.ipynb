# %% [markdown]
# # Reflectron Correction
#
# This workflow mirrors the MATLAB reflectron dataset correction flow from the Atom Probe Toolbox.
# Load an `.epos` dataset, choose the instrument preset measured with the grid electrode, preview the detector map,
# apply the reflectron correction, and save the corrected dataset.

# %%
# Import the reflectron-correction widget workflow.
from pyccapt.calibration.core import share_variables
from pyccapt.calibration.tutorials.tutorials_helpers import helper_reflectron_correction

try:
    variables
except NameError:
    variables = share_variables.Variables()

# %%
# Open the main reflectron correction interface.
helper_reflectron_correction.call_reflectron_correction_workflow(variables)

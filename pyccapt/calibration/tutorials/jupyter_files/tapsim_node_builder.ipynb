# %% [markdown]
# # TAPSim Node Builder Workflow
#
# Use this widget workflow to generate synthetic bulk or tip-shaped specimens, preview precipitates and boundary labels, and export TAPSim-ready ASCII node files plus species maps.

# %%
# %load_ext autoreload
# %autoreload 2

from pyccapt.calibration.tutorials.tutorials_helpers import helper_tapsim_builder

# %%
helper_tapsim_builder.call_tapsim_node_workflow()
